# %%
# you will need to install this library
# !pip install -U PyYAML
import os

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("/content/drive/MyDrive/FourthBrain/FinalProject/Optical-Coherence-Tomography/src/OCT_Model")
from OCT_classifier import *
from data_utils import *

# %%
preProcess = PreProcessing()

# %%
# preProcess.split_data()
# preProcess.split_data(True)

# %%
generators_dic = preProcess.getGenerators()
# Out:
# Found 788 images belonging to 4 classes.
# Found 15 images belonging to 4 classes.
# Found 35 images belonging to 4 classes.
# Found 82 images belonging to 4 classes.

# %%
generator_train  = generators_dic['generator_train']
generator_val    = generators_dic['generator_val']
generator_test   = generators_dic['generator_test']
generator_warmup = generators_dic['generator_warmup']

# %%
clf = OCT_classifier()

# %%
clf.Compile()

# %%
clf.Fit(training_gen=generator_test,validation_gen=generator_test,call_backs_dir="V1")
# Out:
# Epoch 1/5
# 2/2 [==============================] - 16s 2s/step - loss: 1.6727 - accuracy: 0.2708 - val_loss: 1.3386 - val_accuracy: 0.3438
# Epoch 2/5
# 2/2 [==============================] - 1s 257ms/step - loss: 1.3670 - accuracy: 0.3216 - val_loss: 1.1744 - val_accuracy: 0.4737
# Epoch 3/5
# 2/2 [==============================] - 0s 225ms/step - loss: 1.2498 - accuracy: 0.5943 - val_loss: 1.0775 - val_accuracy: 0.6316
# Epoch 4/5
# 2/2 [==============================] - 0s 262ms/step - loss: 1.1987 - accuracy: 0.5208 - val_loss: 0.9933 - val_accuracy: 0.7188
# Epoch 5/5
# 2/2 [==============================] - 0s 305ms/step - loss: 0.9693 - accuracy: 0.5029 - val_loss: 1.1611 - val_accuracy: 0.4737

# %%
y_proba,y_pred = clf.Predict(test_gen=generator_val)
y_true = generator_val.classes

# %%
clf.Evaluate(y_true=y_true,y_pred=y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.29      0.27         7
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         1
#            3       0.14      0.20      0.17         5
#
#     accuracy                           0.20        15
#    macro avg       0.10      0.12      0.11        15
# weighted avg       0.16      0.20      0.18        15
#
# [[2 0 0 5]
#  [1 0 0 1]
#  [1 0 0 0]
#  [4 0 0 1]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
